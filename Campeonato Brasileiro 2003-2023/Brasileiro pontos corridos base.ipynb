# %%
import pandas as pd

base = pd.read_excel("Brasileiro pontos corridos.xlsx")

base_2023 = base.copy()

df_2023 = base_2023[base_2023['season'] == 2023]

df_2023_sorted = df_2023.sort_values(by=['points', 'won'], ascending=False)

base_2023.loc[base_2023['season'] == 2023] = df_2023_sorted.values

display(base_2023)

base_2023.to_excel("Brasileiro Pontos corridos 2003-2023.xlsx", index=False)
# Out:
#      season  place acronym        team  points  played  won  draw  loss  \
# 0      2003      1     CRU    Cruzeiro     100      46   31     7     8
# 1      2003      2     SAN      Santos      87      46   25    12     9
# 2      2003      3     SAO    SaoPaulo      78      46   22    12    12
# 3      2003      4     SCA  SaoCaetano      74      46   19    14    13
# 4      2003      5     CFC    Coritiba      73      46   21    10    15
# ..      ...    ...     ...         ...     ...     ...  ...   ...   ...
# 423    2023     16     ECB       Bahia      44      38   12     8    18
# 424    2023     17     SAN      Santos      43      38   11    10    17
# 425    2023     18     GOI       Goias      38      38    9    11    18
# 426    2023     19     CFC    Coritiba      30      38    8     6    24
# 427    2023     20     AMG  America-MG      24      38    5     9    24
#
#      goals_for  goals_against  goals_diff
# 0          102             47          55
# ...
